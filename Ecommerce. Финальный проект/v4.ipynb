# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Даниил, привет!👋</b>
#
# Это Арсен. Здесь стандартный блок с типами комментариев. Большой цифрой в углу комментария буду подписывать номер проверки, на которой его оставил.
#
# <br/>
# <br/>
#
# <div style="font-size: 300%; font-weight:bold">1</div>
# <div class="alert alert-success">
#     <h4>Комментарий ревьюера: Все отлично! 👍<a class="tocSkip"></h4>
# <p>
# В случае, если решение на отдельном шаге является полностью правильным.
# </p>
# </div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </p>
# </div>
#
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">1</div>
#
# <div style="border:solid Chocolate 2px; padding: 10px">
#
# <b>Промежуточный итог</b>
#
# Даниил, для начала хорошо, но надо посильнее проработать некоторые моменты. В комментариях всё написал.
#
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">2</div>
#
# <div style="border:solid Chocolate 2px; padding: 10px">
#
# <b>Промежуточный итог</b>
#
# Даниил, привет!
#
# Двигаемся в нужном направлении, это отлично! Продолжаем работать)
#
# Кстати, в презентацию давай контекста добавим, т. е. цели, задачи и т. д.
#
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">3</div>
#
# <div style="border:solid Chocolate 2px; padding: 10px">
#
# <b>Промежуточный итог</b>
#
# Даниил, привет!
#
# Рад видеть, что ты продолжаешь работу над проектом!
#
# Со статистикой уже хорошо, надо только немного скорректировать. Не забудь разобраться с дублями, без этого у нас в анализе слишком много лишних данных.
#
# </div>

# %% [markdown]
# # Финальный проект. E-commerse. Выявление профилей потребления.

# %% [markdown]
# ## Введение

# %% [markdown]
# ## Материалы

# %% [markdown]
# Презентация: https://drive.google.com/file/d/1XsO6BO4WwoRWO7widU79qBdByCphJHmX/view?usp=sharing

# %% [markdown]
# ### Цель иследования
# Создание медотики сегментирования пользователей для увеличения выручки путем улучшение пользовательского опыта с помощью пресонализированных предложений.

# %% [markdown]
# ### Описание данных
#
# Датасет описывает транзакции интернет-магазина товаров для дома и быта «Пока
# все ещё тут». <br>
# Колонки в ecommerce_dataset_upd.csv :
# - date — дата заказа;
# - customer_id — идентификатор покупателя;
# - order_id — идентификатор заказа;
# - product — наименование товара;
# - quantity — количество товара в заказе;
# - price — цена товара.

# %% [markdown]
# ### План работы

# %% [markdown]
# 1. Подготовка и изучение данных:
#     - Подключение библиотек
#     - Загрузка и знакомство с данными
#     - Проверка дубликатов
#     - Проверка пропусков
#     - Типы данных
#     - Ошибки данных
#     - Вывод
# 2. Иследовательский анализ данных:
#     - Выручка
#     - Выручка с покупателя
#     - Самые популярные товары
#     - Сымые популярыные товары по сезонам
# 3. Сегментация пользователей:
#     - По среднему чеку
#     - По частоте покупок
#     - По количеству товаров в заказе
#     - Вывод
# 4. Проверка статистических гипотез:
#     - Статистическая значимость различий выручки
#     - Статистическая занчимость различий среднего чека
# 5. Рекомендации
# 6. Вывод

# %% [markdown]
# ## 1. Подготовка и изучение данных

# %% [markdown]
# ### Импорт библиотек

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as st
import numpy as np

# %% [markdown]
# ### Загрузка данных

# %%
ecommerce = pd.read_csv('https://code.s3.yandex.net/datasets/ecom_dataset_upd.csv')

# %% [markdown]
# Посмотрим первые 10 строк нашей таблицы

# %%
ecommerce.head(10)
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 5  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 6  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 7  2018100108  375e0724-f033-4c76-b579-84969cf38ee2     68479
# 8  2018100108  6644e5b4-9934-4863-9778-aaa125207701     68478
# 9  2018100109  c971fb21-d54c-4134-938f-16b62ee86d3b     68480
#
#                                              product  quantity  price
# 0    Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12,...         1  194.0
# 2                        Радермахера d-12 см h-20 см         1  112.0
# ...

# %% [markdown]
# Также выведем основную информацию о таблице

# %%
ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7474 entries, 0 to 7473
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7474 non-null   int64
#  1   customer_id  7474 non-null   object
#  2   order_id     7474 non-null   int64
#  3   product      7474 non-null   object
#  4   quantity     7474 non-null   int64
#  5   price        7474 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 350.5+ KB

# %% [markdown]
# Итого мы имеем 6 столбцов и 7474 строк

# %% [markdown]
# ### Проверка дубликатов

# %%
ecommerce.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Полных дубликатов нет

# %% [markdown]
# ### Не полные дупликаты

# %% [markdown]
# Тогда проводим проверку на наличие дубликатов в определенных колонках, содержащих важные переменные для анализа, такие как название товара и id заказа и id покупателя.

# %%
ecommerce[['customer_id', 'order_id', 'product']].duplicated().sum()
# Out:
# 1886

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Нам еще надо убедиться, что в данных выполняется соотношение 1 заказ - 1 дата - 1 покупатель. При этом мы знаем, что возможны технические дубли, которые надо удалить, но за каждой записью должен быть реально оплаченный заказ, который и нужен в анализе. Так как нам хочется сохранить как можно больше данных в анализе, придётся посмотреть на них поближе и разобраться, что можно оставить, а что надо удалить.
# </p>
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">2</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Мы увидели, что дубликаты есть, надо же с ними что-то сделать теперь (см. предыдущий комментарий). Плюс надо не забыть посмотреть, не попали ли у нас разные пользователи в один заказ.
# </p>
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">3</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Даниил, если у нас есть в данных ошибки, то их надо удалить. Задублировавшиеся при выгрузке заказы - это как раз те самые технические ошибки. Нет смысла включать их в анализ и пытаться планировать дальнейшие шаги, основываясь на несуществующих заказах.
#
# Это уже третий комментарий в этом месте, надо этот момент проработать.
# </p>
# </div>

# %% [markdown]
# ### Проверка пропусков

# %%
ecommerce.isna().sum()
# Out:
# date           0
# customer_id    0
# order_id       0
# product        0
# quantity       0
# price          0
# dtype: int64

# %% [markdown]
# Пропусков также нет

# %% [markdown]
# ### Типы данных

# %% [markdown]
# Из 6 столбцов неверный тип данных только у date. Меняем на datetime

# %%
ecommerce['date'] = pd.to_datetime(ecommerce['date'], format = '%Y%m%d%H')

# %% [markdown]
# ### Аномалии и ошибки в данных

# %% [markdown]
# Посмотрим как распределены цены товаров.

# %%
plt.subplots(figsize = (10,10))
sns.scatterplot(x = ecommerce['date'], y = ecommerce['price'])
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">2</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Даниил, цена на сушилку адекватная, это можно в интернете проверить, плюс она не так уж сильно отличается от остальных.
#
# Да, там всего одна покупка, но здесь речь о подходе в целом. Давай её вернём обратно.
# </p>
# </div>

# %% [markdown]
# Также стоит посмотреть количество товара в заказе на аномалии

# %%
plt.subplots(figsize = (10,10))
sns.scatterplot(x = ecommerce['date'], y = ecommerce['quantity'])
plt.show()

# %% [markdown]
# Здесь также видим подозрительно высокое значение. Смотрим

# %%
ecommerce.query('quantity > 500')
# Out:
#                     date                           customer_id  order_id  \
# 5456 2019-06-18 15:00:00  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6     71743
#
#                                                 product  quantity  price
# 5456  Вантуз с деревянной ручкой d14 см красный, Bur...      1000  675.0

# %% [markdown]
# Ошибку понял. Удаляю вантузы.

# %%
ecommerce = ecommerce[ecommerce['quantity'] < 500]

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Даниил, первый вопрос, который возникает - почему?
#
# Обрати внимание, у нас нет задачи «причесать» данные, удалив из них всё, что нам не нравится. Часто именно в выбросах проявляются особенности данных, которые были малозаметны в общей массе наблюдений. Отобрать подозрительные наблюдения по квантилям, по количеству или по графикам для более пристального рассмотрения - отличная идея. Удалять, не глядя - плохая практика. С каждым удалённым наблюдением мы теряем информацию. Если мы это делаем, то должны понимать, что получаем взамен.
#
# Также важно при принятии решения об удалении учитывать поставленную задачу. Если, например, мы анализируем просмотры посетителями объявлений где-нибудь на большой площадке, то мы будем очищать датасет от пользователей с запредельным количеством просмотров, потому что вероятнее всего это боты, которые не интересны нам с точки зрения поставленной задачи. В таком случае удаление (осознанное!) оправдано и необходимо.
#
# Если у нас стоит задача проанализировать покупателей магазина (вот так, без конкретики), то мы не можем просто взять и кого-то не рассматривать. Можно выделить выбросы в отдельную группу и сделать по ним отдельный анализ, но не стоит делать вид, что их не существует.
#
# С точки зрения бизнеса аномалии нам очень интересны. Было бы странно сходу выбросить из анализа 1% клиентов, генерирующих больше всего выручки, только потому что они слишком сильно от остальных отличаются. Поставив себя на место заказчика, будем ли мы довольны таким анализом?
#
# Даже технические ошибки правильнее будет удалять после того, как мы их идентифицировали как ошибки и придумали, что дальше с ними делать (забыть/отдать кому-то/исправлять и т. д.).
#
# Здесь явно можно удалить только заказ на 1000 вантузов (и дубли, конечно). На созвоне мы обсуждали, что это тестовый заказ, который забыли убрать из базы. Остальных надо вернуть.
# </p>
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Итого в данныз не было пропусков или полных дубликатов. Было некоторое количество выбросов, которые мы почистили. Далее переходим к иследовательскому анализу.

# %% [markdown]
# ## 2. Иследовательский анализ данных

# %% [markdown]
# ### Выручка

# %% [markdown]
# Для начала посмотрим выручку по годам. Для этого в таблицу добавим столбец с годом. Также добавим столбец с месяцами и стлбец с выручкой.

# %%
ecommerce['year'] = ecommerce['date'].dt.year
ecommerce['month'] = ecommerce['date'].dt.month
ecommerce['revenue'] = ecommerce['quantity'] * ecommerce['price']

# %% [markdown]
# Создадим сводную таблицу с выручкой

# %%
ecom_sum_year = ecommerce.pivot_table(index=['year'], values = 'revenue', aggfunc='sum').reset_index()
ecom_sum_year.head()
# Out:
#    year       revenue
# 0  2018  1.194702e+06
# 1  2019  3.314206e+06
# 2  2020  1.740363e+05

# %% [markdown]
# Строим график

# %%
sns.barplot(x=ecom_sum_year['year'], y=ecom_sum_year['revenue'])
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Мы нашли здесь не выручку, а средний чек по годам.
# </p>
# </div>

# %% [markdown]
# 2019 год уврено ледирует по выручке что не удивительно, так как полные данные у нас лишь за 2019 год.

# %% [markdown]
# ### Выручка по годам и месецам

# %%
ecommerce.groupby(['year', 'month']).agg({'revenue': 'sum'}).plot(kind = 'bar', figsize=(7,7), legend=False)
plt.show()

# %% [markdown]
# Лидер по выручке это октябрь 2018 года, а на втором месте иьнь 2019. За все время наблюдается снижение выручки. Самая низкая выручка 2019 год октябрь.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# У нас достаточно небольшой период по времени, поэтому стоит рассматривать динамику с разделением на месяц+год, а не просто смотреть на значения по месяцам.
# </p>
# </div>

# %% [markdown]
# Здесь сильно выделяеться июнь. Это может быть связано с началом всеобщих поездок на дачи. Далее посмотрим выручку по сезонам. Для этого напишем функцию которая создаст нам столбец с временами года.

# %%
def seas(mon): # Функция которая присваевает время года исходя из номера месяца
    if mon == 1 or mon == 2 or mon == 12:
        return 'winter'
    elif mon == 3 or mon == 4 or mon ==  5:
        return 'spring'
    elif mon == 6 or mon == 7 or mon == 8:
        return 'summer'
    elif mon == 9 or mon == 10 or mon == 11:
        return 'autumn'

# %%
ecommerce['season'] = ecommerce['month'].apply(seas) # пременяем функцию

# %%
ecom_sum_season = ecommerce.pivot_table(index=['season'], values = 'revenue', aggfunc='sum').reset_index()

# %%
sns.barplot(x=ecom_sum_season['season'], y=ecom_sum_season['revenue'])
plt.show()

# %% [markdown]
# По выручке лидируют осень и зима это может быть связано с тем что у нас имеются в данных 2 зимы и 2 осени, а весна и лето всего одни.

# %% [markdown]
# ### Выручка с покупателя

# %% [markdown]
# Смотрим как распределена общая выручка с каждого покупателя.

# %%
max_customer_revenue = ecommerce.pivot_table(index = 'customer_id', values = 'revenue', aggfunc='sum').reset_index()

# %%
plt.subplots(figsize = (7,7))
sns.scatterplot(x = max_customer_revenue['customer_id'], y = max_customer_revenue['revenue'])
plt.xticks([])
plt.show()

# %% [markdown]
# Видно что большенство покупателей тратят до 15000, но встречаются тарты свыше 150000.

# %% [markdown]
# ### Самые популярные товары

# %% [markdown]
# Посмотрим товары который чаще всего покупают

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь мы посчитали количество проданных товарных единиц. Это же не то же самое, что количество заказов, поэтому будет некорректно говорить, что крепеж для пружины купили 320 раз.
# </p>
# </div>

# %% [markdown]
# Я имел в виду сколько единиц товар купили. Не правильно напасал. Поправил.

# %%
most_popular_items = ecommerce.pivot_table(index='product', values = 'quantity', aggfunc='sum').reset_index()
most_popular_items.sort_values(by = 'quantity',ascending = False).head(10)
# Out:
#                                                 product  quantity
# 835                           Муляж ЯБЛОКО 9 см красное       618
# 191    Вешалки мягкие для деликатных вещей 3 шт шоколад       335
# 663                 Крепеж для пружины дверной, 1107055       320
# 837                Муляж Яблоко зеленый 9 см полиуретан       308
# 1199  Пружина дверная 240 мм оцинкованная (Д-19 мм) ...       300
# 1453      Ручка-скоба РС-100 белая *Трибатрон*, 1108035       201
# 1114  Плечики пластмассовые Размер 52 - 54 Тула 1205158       160
# 7      Ёрш унитазный с деревянной ручкой , Ваир 1712012       123
# 1611        Стяжка оконная с болтом СТ-55 цинк, 1108354       113
# 777                 Муляж Банан желтый 21 см полиуретан       109

# %% [markdown]
# Самый популярный товар купили 618 едениц. Это муляж красного яблока.

# %%
plt.subplots(figsize = (10,10))
sns.scatterplot(x = most_popular_items['product'], y = most_popular_items['quantity'])
plt.xticks([])
plt.show()

# %% [markdown]
# В основном товары покупают до 50 едениц, но встречаются покупки более 300.

# %% [markdown]
# ### Самые популярные товары по сезонам

# %%
most_popular_items_seas = ecommerce.pivot_table(index=['season','product'], values = 'quantity', aggfunc='sum').reset_index()
most_popular_items_seas.sort_values(by = 'quantity', ascending=False)
# Out:
#       season                                            product  quantity
# 2037  summer   Вешалки мягкие для деликатных вещей 3 шт шоколад       335
# 372   autumn                          Муляж ЯБЛОКО 9 см красное       318
# 543   autumn  Пружина дверная 240 мм оцинкованная (Д-19 мм) ...       300
# 1299  spring                          Муляж ЯБЛОКО 9 см красное       300
# 273   autumn                Крепеж для пружины дверной, 1107055       300
# ...      ...                                                ...       ...
# 2217  summer  Пеларгония зональная диам. 12 см розово-малино...         1
# 2216  summer  Пеларгония зональная диам. 12 см розово-красна...         1
# 882   autumn  Флокс метельчатый сорт Земляничное суфле, диам...         1
# 883   autumn  Флокс метельчатый сорт Катенька-Катюша, диамет...         1
# 0     autumn  Tepмокружка AVEX Recharge 500 мл голубой AVEX0681         1
#
# [3473 rows x 3 columns]

# %%
plt.subplots(figsize = (10,10))
sns.scatterplot(x = most_popular_items_seas['season'], y = most_popular_items_seas['quantity'])
#plt.xticks([])
plt.show()

# %% [markdown]
# Осенью количесто покупаемых товаров больше, чем в других сезонах. Не совсем понятно почему так. Ведь кажеться что должно быть лето или весна.

# %% [markdown]
# ### Помесячная динамика количества покупателей

# %%
ecommerce.groupby(['year', 'month']).agg({'customer_id': 'nunique'}) \
         .plot(marker='o', figsize=(14,7), grid=True, legend=False)
plt.ylim(0,300)
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">2</div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# На таких графиках лучше добавлять 0 в диапазон вертикальной оси, чтобы не искажать восприятие глубины этих провалов. Здесь кажется, что у нас вообще продажи останавливались, хотя на самом деле там была просадка на 30%, что тоже неприятно но не настолько.
# </p>
# </div>

# %% [markdown]
# График достаточно не спокойный. Видно что в январе 2019 года наблюдается сильный провал. Это сожно объяснить новогодними каникулами. Потом идет такой же резкий подъем. И несколько месяцев показатель держится на одном уровне. Далее опять же достаточно резкий спад. А далее происходит очень резкий взлет пользователей. То есть летом у нас достаточно сильно просядают показатели покупателей. Сложно сказать нормально такая картина или нет. Конец 2019 года радует, но возможно что этот резкий рост также резко упадет обратно. В целом мне кажется такая ситуация не совсем хорошей.

# %% [markdown]
# ### Помесечная динамика количества закакзов

# %%
ecommerce.groupby(['year', 'month']).agg({'order_id': 'nunique'}) \
         .plot(marker='o', figsize=(14,7), grid=True, legend=False)
plt.ylim(0,300)
plt.show()

# %% [markdown]
# Этот график подозрительно похож на предыдущий, только значения другие. Следовательно про него можно сказать тоже самое.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Давай посмотрим еще на помесячную динамику количества покупателей, количества заказов, и сделаем вывод о состоянии нашего магазина.
# </p>
# </div>

# %% [markdown]
# ## 3. Сегментация пользователей

# %% [markdown]
# ### Сегментация по среднему чеку

# %% [markdown]
# Проведем сегментацию по среднему чеку среди пользователей.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px;">1</div>
# <div class="alert alert-success">
# <h4>Комментарий ревьюера: Все отлично! 👍<a class="tocSkip"></h4>
# <p>
# Здесь плюс за корректный расчет среднего чека!
# </p>
#     </div>

# %%
avg_check = ecommerce.pivot_table(index = 'customer_id', values = ['revenue','order_id'], aggfunc={'revenue':'sum','order_id':'nunique'}).reset_index()

# %%
avg_check['avg'] = avg_check['revenue'] / avg_check['order_id']

# %%
def avg(check): # Функция которая сегментирует по среднему чеку
    if check < 5000:
        return 'маленький'
    elif check > 5000 and check < 20000:
        return 'средний'
    elif check > 20000:
        return 'большой'

# %%
avg_check['segment'] = avg_check['avg'].apply(avg) # Пременяем функцию

# %% [markdown]
# Строим график

# %%
plt.subplots(figsize = (7,7))
sns.scatterplot(x = avg_check['customer_id'], y = avg_check['avg'])
plt.xticks([])
plt.show()

# %% [markdown]
# В основном средний чек у большенства пользователей держится до 10000.

# %%
avg_check_count = avg_check.pivot_table(index = 'segment', values = 'order_id',aggfunc='count').reset_index()
plt.pie(avg_check_count['order_id'], labels = avg_check_count['segment'])
plt.show()

# %% [markdown]
# Самая большая группа это маленький средний чек. Она довольно слиьно доминирует над другими. Это может быть связано достаточно с большим количеством факторов. Например со асортиментом или ценообразованием.

# %% [markdown]
# ### Сегментация по количеству покупок

# %%
count_purchase = ecommerce.pivot_table(index = 'customer_id', values = 'order_id', aggfunc='nunique').reset_index()
def cnt(pur): # Функция которая сементирует по количеству покупок
    if pur == 1:
        return 'одна покупка'
    elif pur > 1 and pur <= 3:
        return 'малое количество покупок'
    elif pur >= 4 and pur < 10:
        return 'среднее количество покупок'
    elif pur >= 10 and pur <= 30:
        return 'большое количество покупок'
    elif pur >=31:
        return 'постоянный покупатель'
count_purchase['segment'] = count_purchase['order_id'].apply(cnt)

# %%
plt.subplots(figsize = (7,7))
sns.scatterplot(x = count_purchase['customer_id'], y = count_purchase['order_id'])
plt.xticks([])
plt.show()

# %% [markdown]
# Люди покупают до 3 раз. Все что выше редкость. Ниже сторим график по сегментам.

# %%
purchase_count = count_purchase.pivot_table(index = 'segment', values = 'order_id',aggfunc='count').reset_index()
plt.subplots(figsize = (15,8))
sns.barplot(x=purchase_count['segment'], y=purchase_count['order_id'])
plt.show()

# %% [markdown]
# Как видно больше всего тех кто купил один раз. То есть люди не возвращаются обратно. Далее люди купившие до 3 раз. Это уже лучше чем один, но все же не то. Если люди покупают что-то для дачи, то это значит что они готовы покупать постояно. Так как в доме всегда что-то нужно. Три оставшиеся группы почти не видны на таком маштабе. Взглянем более детально.

# %%
plt.subplots(figsize = (15,8))
sns.barplot(x=purchase_count['segment'], y=purchase_count['order_id'])
plt.ylim(0,10)
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold">1</div>
# <div class="alert alert-warning">
# <h4>Комментарий ревьюера: Есть замечания и рекомендации 💡<a class="tocSkip"></h4>
# <p>
# Если у нас два постоянных покупателя и один, купивший много, то с лояльностью всё-таки есть определенные проблемы)
# </p>
# </div>

# %% [markdown]
# Как не странно постоянных покупателей больше чем тех кто просто купил много. Возможно с лояльностью покупателей все не так плохо. Мое мнение что это самое важное сегментирование. Именно те клиенты которые покупают регулярно самые ценные.

# %% [markdown]
# ### Сегментация по количеству товаров.

# %% [markdown]
# Также посмотрим сегментацию по количеству товаров

# %%
count_item = ecommerce.pivot_table(index = 'customer_id', values = 'quantity',aggfunc = 'sum').reset_index()

# %%
def cnti(item): # Функция которая сегментирует по количеству товара
    if item < 10:
        return 'очень малое количество товара'
    elif item >= 10 and item <= 50:
        return 'малое количество товара'
    elif item >= 51 and item <= 100:
        return 'среднее количество товара'
    elif item >= 101 and item <= 300:
        return 'большое количество товара'
    elif item >=301:
        return 'очень бльшое количество товара'
count_item['segment'] = count_item['quantity'].apply(cnti)

# %%
plt.subplots(figsize = (10,10))
sns.scatterplot(x = count_item['customer_id'], y = count_item['quantity'])
plt.xticks([])
plt.show()

# %% [markdown]
# Люди покупают до 50 товаров.

# %%
item_count = count_item.pivot_table(index = 'segment', values = 'quantity',aggfunc='count').reset_index()
plt.subplots(figsize = (20,8))
sns.barplot(x=item_count['segment'], y=item_count['quantity'])
plt.show()

# %% [markdown]
# Самая большая группа это те кто купил до 50 товаров.

# %%
plt.subplots(figsize = (15,8))
sns.barplot(x=item_count['segment'], y=item_count['quantity'])
plt.ylim(0,100)
plt.show()

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">1</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Здесь давай остановимся на каком-то конкретном подходе и приготовим подробные описания для полученных сегментов. Мы это делаем для того, чтобы понять, какие особенности и различия сегментов можно использовать для построения дальнейшего взаимодействия. Когда мы такие различия найдем, нам надо будет использовать статистический анализ, чтобы убедиться, что они не случайны. После этого нам надо будет уже подготовить рекомендации по работе с каждым сегментом.
#
# В рекомендациях ниже у нас по сути только персонализированный маркетинг и программы лояльности, этого пока недостаточно.
# </p>
# </div>

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">2</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Даниил, я понимаю, что статистический анализ - это сложно. Совершенно нормально испытывать с ним трудности. Тем не менее он является обязательной частью этого проекта, поэтому нам надо сформулировать и проверить гипотезы. Сделай так, как понимаешь, я объясню ошибки, если они будут, и в процессе есть шанс, что станет еще немного понятнее.
# </p>
# </div>

# %% [markdown]
# ## 4. Рекомендации

# %% [markdown]
# В первую очередь считаю что нужно ориентироваться на сегментацию по количеству совершения покупок. Для нас должны быть в приоритете клиенты которые регулярно совершают покупки, и нужно стремится их количество наращивать. Ведь повторные покупки играют важную роль в успехе бизнеса и имеют значительное влияние на его долгосрочную устойчивость и прибыльность.  Вот несколько причин, почему повторные покупки так важны:
#
# - Увеличение выручки: Повторные покупки способствуют увеличению общей выручки магазина или компании. Когда покупатель возвращается и совершает дополнительные покупки, это добавляет дополнительные доходы, не требуя больших затрат на маркетинг и привлечение новых клиентов.
#
# - Снижение затрат на маркетинг: Привлечение новых клиентов обычно требует больших затрат на маркетинг и рекламу. В то время как у вас уже есть база клиентов, повторные покупки позволяют снизить затраты на маркетинг и фокусироваться на удержании и увеличении активности существующих клиентов.<br>
#
# Привлечение покупателей к повторным покупкам является важной частью стратегии удержания клиентов. Делать это можно разными способами в первую очередь это конечно персонализированный маркетинг и программы лояльности.
#
# Дадим характеристики каждому сегменту.
#
# - Одна покупка: Все клиенты которые совершили за все время всего одну покупку. Что-то делать для таких клиентов персонально не стоит, так как их очень много и может не хватить ресурсов. Делать упор стоит имено на превый контакт, первую покупку. То есть покупатель должен остатся доволен сервесом, и это может перенести его в следущую группу.
#
# - Мало покупок: Пользователи которые совершили больше одной но меньше трех покупок. Таким пользоваетелям можно напоминать о нас с помощью e-mail рассылок или push уведомлений. Содержание может рассказывать о новинках асортимента или акциях. Для них наверное тоже не стоит делать что-то особеное. Информирования достаточно.
#
# - Среднее количество покупок: Пользователи совершившие от 4 до 10 покупок. Для таких пользоваетелей стоит пребегнуть к скидкам на повторную покупку. Предлажив скидку на следующую покупку сразу после завершения предыдущей. Это может стимулировать клиентов вернуться за следующим товаром.
#
# - Большое количетво покупок: Пользователи совершивши более 10 но менее 30 покупок. Это уже вашная часть клиентов. Им можно предлогать скидки на их любимую категория товара или даже на конкретный товар без превязки к чему либо. Если клиент сделал так много покупок то скорее всего он станет постояным клиентом
#
# - Постоянные клиенты: Если пользователь попал в эту группу значит его все устраивает и он готов покупать и дальше. Самые ценные клиенты. Для них можно использовать персональные рассылки, например поздравительные письма. Специальные предложения для постоянных клиентов, эксклюзивные скидки и акции именно для постоянных клиентов. Это будет демонстрировать, что вы цените их лояльность.
#
# Также можно ввести программу лояльности с разными уровнями. Это может быть система накопления бонусов за каждую покупку, которые потом можно будет обменять на скидки или подарки.
#
# Основное различие между сегментами в количестве совершёных покупок. Чем их больше тем выше статус. Постоянные клиенты очень лояльны, легче переносят колебания цен. Также у них выше LTV. Они являются фундаментом бизнеса. Можно предворительно сформулиовать гепотизы:
#
# 1. Средний чек
#     - H0 - средний чек у постоянных клиентов выше чем у других
#     - H1 - средний чек не отличается
# 2. Выручка
#     - H0 - Выручка у постоянных клиентов выше чем у других
#     - H1 - Выручка не отличается

# %% [markdown]
# ## Проверка статистических гипотез

# %% [markdown]
# ### Гепотеза о среднем чеке

# %% [markdown]
# H0 - средний чек у постоянных клиентов выше чем у других
# H1 - средний чек не отличается

# %% [markdown]
# Добавим столбец с сегментами по количеству покупок в основной датафрейм. И сразу проверим правлильно ли все получилось.

# %%
ecommerce['count'] = ecommerce.groupby('customer_id')['order_id'].transform('nunique')
ecommerce['segment'] = ecommerce['count'].apply(cnt)
ecommerce.groupby('segment')['customer_id'].nunique()
# Out:
# segment
# большое количество покупок       1
# малое количество покупок       889
# одна покупка                  1553
# постоянный покупатель            2
# среднее количество покупок       5
# Name: customer_id, dtype: int64

# %% [markdown]
# Смотрим в предыдущей табличке

# %%
purchase_count
# Out:
#                       segment  order_id
# 0  большое количество покупок         1
# 1    малое количество покупок       889
# 2                одна покупка      1553
# 3       постоянный покупатель         2
# 4  среднее количество покупок         5

# %% [markdown]
# Все сходиться. Идем дальше.

# %%
avg_check2 = ecommerce.pivot_table(index = 'customer_id', values = ['revenue','order_id'], aggfunc={'revenue':'sum','order_id':'nunique'}).reset_index()
avg_check2['segment'] = avg_check2['order_id'].apply(cnt)
avg_check2['avg_check'] = avg_check2['revenue'] / avg_check2['order_id']
avg_check2
# Out:
#                                customer_id  order_id  revenue  \
# 0     000d6849-084e-4d9f-ac03-37174eaf60c4         1    555.0
# 1     001cee7f-0b29-4716-b202-0042213ab038         1    442.0
# 2     00299f34-5385-4d13-9aea-c80b81658e1b         1    914.0
# 3     002d4d3a-4a59-406b-86ec-c3314357e498         1   1649.0
# 4     003bbd39-0000-41ff-b7f9-2ddaec152037         1   2324.0
# ...                                    ...       ...      ...
# 2445  ff601403-b094-4b86-9ac6-264d725b9277         2   1739.0
# 2446  ffaeab76-3a8d-49ee-860f-17273b2fc8a2         1   1191.0
# 2447  ffb5976a-7a4d-460b-95c4-5ffaba31cb24         1    778.0
# 2448  ffb80538-3fda-4351-8ea9-9d2bec58bb07         1    974.0
# 2449  ffe82299-3f5b-4214-87fe-3d36ecccfac3         1    577.0
#
#                        segment  avg_check
# 0                 одна покупка      555.0
# 1                 одна покупка      442.0
# 2                 одна покупка      914.0
# 3                 одна покупка     1649.0
# ...

# %%
avg_check_regular_customer = avg_check2.query('segment == "постоянный покупатель"')
avg_check_much_customer = avg_check2.query('segment == "большое количество покупок"')
avg_check_middle_customer = avg_check2.query('segment == "среднее количество покупок"')
avg_check_small_customer = avg_check2.query('segment == "малое количество покупок"')
avg_check_one_customer = avg_check2.query('segment == "одна покупка"')

# %%
alpha = 0.05 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(avg_check_one_customer['avg_check'],avg_check_regular_customer['avg_check'],equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.4784663369499912
# Не получилось отвергнуть нулевую гипотезу

# %%
def o(one,two):
    alpha = 0.05 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

    results = st.ttest_ind(one['avg_check'],two['avg_check'],equal_var=False)

    print('p-значение:', results.pvalue)

    if results.pvalue < alpha:
        print('Отвергаем нулевую гипотезу')
    else:
        print('Не получилось отвергнуть нулевую гипотезу')

# %%
o(avg_check_regular_customer, avg_check_middle_customer)
# Out:
# p-значение: 0.5617762199519591
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Я если честно даже не знаю с какой стороны подступится. Не особо пониматю даже какой метод проверки применить. Выбал Т-тест из описание мне показалось что он подходит. Если направите в правильное русло буду благодарен.

# %% [markdown]
# <div style="font-size: 300%; font-weight:bold; padding: 10px">3</div>
# <div class="alert alert-block alert-danger">
# <h4>Комментарий ревьюера: Нужна доработка 🤔<a class="tocSkip"></h4>
# <p>
# Даниил, технически ты всё правильно сделал. Правильно составил выборки из покупателей для сравнения сегментов и посчитал для каждого покупателя средний чек. Это круто, молодец!
#
# Сейчас проблема в том, что у нас в топовых сегментах очень мало людей. 1, 2 и 5 человек - это не тот массив данных, с которым мы можем уверенно использовать статистический анализ. Давай лучше используем проверку гипотез на более массовых сегментах. Например, сравним покупателей с одной покупкой со всеми остальными. В качестве второй гипотезы давай сравним выручку на покупателя.
#
# Есть еще момент. Общая идея применения статистического анализа в нашей ситуации такая. Мы делим группы на сегменты и обнаруживаем между сегментами какие-то различия (по выручке или среднему чеку). Дальше мы пытаемся понять, можно ли на эти различия опираться при принятии решений, или это просто какая-то случайность. Здесь нам и приходит на помощь статистический анализ. Дальше мы составляем рекомендации, которые помимо прочего будут учитывать и результаты стат. проверки. Это всё я к тому, что надо проверку гипотез передвинуть в ходе исследования до составления рекомендаций, а в рекомендациях эти результаты тоже как-то учесть.
# </p>
# </div>
